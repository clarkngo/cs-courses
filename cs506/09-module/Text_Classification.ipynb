# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\peini\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data = keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) = data.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
word_index = data.get_word_index()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step

# %%
word_index = {word:(num+3) for word, num in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2
word_index["<UNUSED>"] = 3

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])
print(decode_review(train_data[0]))
# Out:
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %%
print(len(train_data[0]), len(test_data[1]))
# Out:
# 218 260

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value=word_index["<PAD>"], padding='post', maxlen=256)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value=word_index["<PAD>"], padding='post', maxlen=256)

# %%
print(len(train_data[0]), len(test_data[1]))
# Out:
# 256 256

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(10000, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\peini\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 16)          160000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160289 (626.13 KB)
# Trainable params: 160289 (626.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\peini\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
x_val = train_data[:10000]
y_val = train_labels[:10000]

x_train = train_data[10000:]
y_train = train_labels[10000:]

fitModel = model.fit(x_train, y_train, epochs=40, batch_size=512, validation_data=(x_val, y_val), verbose=1)

results = model.evaluate(test_data, test_labels)

print(results)
# Out:
# Epoch 1/40
# WARNING:tensorflow:From c:\Users\peini\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\peini\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 30/30 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.5615 - val_loss: 0.6909 - val_accuracy: 0.5911
# Epoch 2/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.6878 - accuracy: 0.6360 - val_loss: 0.6843 - val_accuracy: 0.7311
# Epoch 3/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.6779 - accuracy: 0.7458 - val_loss: 0.6716 - val_accuracy: 0.7477
# Epoch 4/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.6592 - accuracy: 0.7569 - val_loss: 0.6501 - val_accuracy: 0.7528
# Epoch 5/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.6298 - accuracy: 0.7816 - val_loss: 0.6181 - val_accuracy: 0.7773
# Epoch 6/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.5912 - accuracy: 0.8025 - val_loss: 0.5792 - val_accuracy: 0.7919
# Epoch 7/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.5466 - accuracy: 0.8199 - val_loss: 0.5378 - val_accuracy: 0.8035
# Epoch 8/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.5005 - accuracy: 0.8369 - val_loss: 0.4982 - val_accuracy: 0.8136
# Epoch 9/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.4567 - accuracy: 0.8511 - val_loss: 0.4588 - val_accuracy: 0.8367
# Epoch 10/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.4158 - accuracy: 0.8657 - val_loss: 0.4256 - val_accuracy: 0.8450
# Epoch 11/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.3807 - accuracy: 0.8755 - val_loss: 0.3981 - val_accuracy: 0.8532
# Epoch 12/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.3515 - accuracy: 0.8826 - val_loss: 0.3771 - val_accuracy: 0.8603
# Epoch 13/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.3261 - accuracy: 0.8915 - val_loss: 0.3579 - val_accuracy: 0.8645
# Epoch 14/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.3051 - accuracy: 0.8933 - val_loss: 0.3437 - val_accuracy: 0.8684
# Epoch 15/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2856 - accuracy: 0.9016 - val_loss: 0.3320 - val_accuracy: 0.8724
# Epoch 16/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2697 - accuracy: 0.9065 - val_loss: 0.3217 - val_accuracy: 0.8750
# Epoch 17/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2549 - accuracy: 0.9105 - val_loss: 0.3136 - val_accuracy: 0.8774
# Epoch 18/40
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2417 - accuracy: 0.9149 - val_loss: 0.3070 - val_accuracy: 0.8785
# Epoch 19/40
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2291 - accuracy: 0.9204 - val_loss: 0.3018 - val_accuracy: 0.8807
# Epoch 20/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2182 - accuracy: 0.9248 - val_loss: 0.2975 - val_accuracy: 0.8818
# Epoch 21/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2079 - accuracy: 0.9271 - val_loss: 0.2952 - val_accuracy: 0.8811
# Epoch 22/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1983 - accuracy: 0.9306 - val_loss: 0.2909 - val_accuracy: 0.8838
# Epoch 23/40
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1895 - accuracy: 0.9349 - val_loss: 0.2886 - val_accuracy: 0.8844
# Epoch 24/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1811 - accuracy: 0.9381 - val_loss: 0.2872 - val_accuracy: 0.8841
# Epoch 25/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1735 - accuracy: 0.9436 - val_loss: 0.2861 - val_accuracy: 0.8844
# Epoch 26/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1663 - accuracy: 0.9470 - val_loss: 0.2866 - val_accuracy: 0.8845
# Epoch 27/40
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1600 - accuracy: 0.9485 - val_loss: 0.2876 - val_accuracy: 0.8824
# Epoch 28/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1532 - accuracy: 0.9503 - val_loss: 0.2854 - val_accuracy: 0.8858
# Epoch 29/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.9535 - val_loss: 0.2901 - val_accuracy: 0.8823
# Epoch 30/40
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1413 - accuracy: 0.9555 - val_loss: 0.2869 - val_accuracy: 0.8860
# Epoch 31/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9584 - val_loss: 0.2880 - val_accuracy: 0.8859
# Epoch 32/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1297 - accuracy: 0.9611 - val_loss: 0.2930 - val_accuracy: 0.8827
# Epoch 33/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1251 - accuracy: 0.9633 - val_loss: 0.2915 - val_accuracy: 0.8862
# Epoch 34/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1201 - accuracy: 0.9662 - val_loss: 0.2940 - val_accuracy: 0.8850
# Epoch 35/40
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1152 - accuracy: 0.9678 - val_loss: 0.2958 - val_accuracy: 0.8859
# Epoch 36/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1109 - accuracy: 0.9693 - val_loss: 0.2983 - val_accuracy: 0.8850
# Epoch 37/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1067 - accuracy: 0.9705 - val_loss: 0.3006 - val_accuracy: 0.8845
# Epoch 38/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1033 - accuracy: 0.9721 - val_loss: 0.3058 - val_accuracy: 0.8830
# Epoch 39/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0988 - accuracy: 0.9729 - val_loss: 0.3071 - val_accuracy: 0.8833
# Epoch 40/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0952 - accuracy: 0.9743 - val_loss: 0.3102 - val_accuracy: 0.8834
# 782/782 [==============================] - 0s 487us/step - loss: 0.3301 - accuracy: 0.8724
# [0.3301462233066559, 0.8723599910736084]

# %%
test_review = test_data[0]
predict = model.predict(np.array([test_review]))
print("Review: "+decode_review(test_review))
print("Prediction: "+str(predict[0]))
print("Actual: "+str(test_labels[0]))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# Review: <START> please give this one a miss br br <UNK> <UNK> and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite <UNK> so all you madison fans give this a miss <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Prediction: [0.08589069]
# Actual: 0

# %%
history_dict = fitModel.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
