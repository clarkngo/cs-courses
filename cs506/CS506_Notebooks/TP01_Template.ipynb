# %% [markdown]
# <center>
#
# # CS506 Programming for Computing
# ## Pandas Tutorial
#
# **Team Members:**
# Team member 1<br>
# Team member 2<br>
# Team member 3<br>
# Team member 4<br>
#
#
#
#
# </center>
#
# ---
#
# ### <center>Before You Start</center>
# *Add preliminary steps and set ups that require to complete this tutorial here ...*
#
# ### <center>Learning Outcomes</center>
# *Add the goal of this tutorial here ...*
#
# ---
#
# # <center>Section 1: Your tutorial begins here.</center>
# <center>_You also can use our HOS document as a template or follow the similar structure from it._</center>
#
# - Step 1 ...
# - Step 2 ...
#
# ---
#
# *The following content shows the example of step-by-step practices along with the instructions and descriptions based on your understanding of each topic from Pandas, Scikit-learn and Pytorch.*
#
# ---
#
# # <center>Installing Python</center>
#
# 1. Write steps here
# * Ensure you have Python 3 installed on your system.
# * **Pandas Library:** Install the Pandas library if you haven't already. You can do this using pip:
#     ```bash
#     pip install pandas
#     ```
# * **Jupyter Notebook (Optional but Recommended):** Jupyter Notebook provides an interactive environment for running Python code and displaying results. You can install it using pip:
#     ```bash
#     pip install notebook
#     ```
# * **Seaborn Library:** Install the Seaborn library:
#     ```bash
#     pip install seaborn
#     ```
#
# # <center> Pandas DataFrame Tutorial with Titanic Dataset </center>
# This notebook demonstrates the core functionality of pandas using the Titanic dataset.

# %% [markdown]
# # Conclusion
#  Write conclusion or summary as appropriate
#
#
#
# # Referenes
#
# 1. McKinney, W. (2010). *Data structures for statistical computing in Python*. In S. van der Walt & J. Millman (Eds.), *Proceedings of the 9th Python in Science Conference* (pp. 51–56). https://doi.org/10.25080/Majora-92bf1922-00a
#
# 2. Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B., Grisel, O., ... & Duchesnay, E. (2011). *Scikit-learn: Machine learning in Python*. *Journal of Machine Learning Research, 12*, 2825–2830. https://jmlr.org/papers/v12/pedregosa11a.html
