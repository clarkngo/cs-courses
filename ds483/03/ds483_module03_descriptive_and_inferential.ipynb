# %%
# Calculate the mean of a data set
sample = [1, 5, 2, 6, 7, 7, 3, 2]
mean = sum(sample) / len(sample)
print(mean)
# Out:
# 4.125

# %%
# Calculate the weighted mean of a data set
sample = [70, 40, 56, 51]
weights = [.10, .30, .50, .40]
weighted_mean = sum(s*w for s,w in zip(sample, weights)) / sum(weights)
print(weighted_mean)
# Out:
# 51.84615384615385

# %%
# Calculate the median of a data set
sample = [2, 1, 3, 5, 7, 58, 24]

def median(values):
    ordered = sorted(values)
    print(ordered)
    n = len(ordered)
    mid = int(n/2) - 1 if n % 2 == 0 else int(n/2)

    if n % 2 == 0:
        return (ordered[mid] + ordered[mid+1]) / 2.0
    else:
        return ordered[mid]

print(median(sample))
# Out:
# [1, 2, 3, 5, 7, 24, 58]
# 5

# %%
# Calculate the mode of a data set
from collections import defaultdict

sample = [5, 6, 3, 6, 5, 8, 2, 4]

def mode(values):
    counts = defaultdict(lambda: 0)
    for s in values:
        counts[s] += 1
    max_count = max(counts.values())
    modes = [v for v in set(values) if counts[v] == max_count]
    return modes

print(mode(sample))
# Out:
# [5, 6]

# %%
# Calculate the mode of a data set
from collections import defaultdict

sample = [5, 6, 3, 6, 5, 8, 2, 4]

def mode(values):
    counts = defaultdict(lambda: 0)
    for s in values:
        counts[s] += 1
    max_count = max(counts.values())
    modes = [v for v in set(values) if counts[v] == max_count]
    return modes

print(mode(sample))
# Out:
# [5, 6]

# %%
# Calculate the standard deviation of a data set
from math import sqrt

data = [5, 6, 8, 3, 7, 16, 18]

def variance(values):
    mean = sum(values) / len(values)
    _variance = sum((v - mean) ** 2 for v in values) / len(values)
    return _variance

def std_dev(values):
    return sqrt(variance(values))

print(std_dev(data))
# Out:
# 5.291502622129181
