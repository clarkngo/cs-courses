# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

# make sure tensorflow and Keras are installed. Use !pip if you are running the code on Google Colab
# pip install tensorflow
# pip install keras
# pip install keras-utils

# Helpful ML imports used later
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
print('Imports complete')
# Out:
# Imports complete

# %%
# We are going to work on a classification problem
# The dataset is the famous penguins dataset available here: https://github.com/allisonhorst/palmerpenguins
# Also see: https://www.kaggle.com/parulpandey/penguin-dataset-the-new-iris
# The dataset has been modified to make all features numeric, except for the species column
data = pd.read_csv('penguins_cleaned_ds620.csv')
print('Data loaded. Rows:', data.shape[0], 'Columns:', data.shape[1])
# Out:
# Data loaded. Rows: 333 Columns: 5

# %%
# Question #1: How many features are there in the dataset? Show the code that extracts this number
# We'll try to detect the target (species) column automatically and count the remaining columns as features
possible_targets = ['species', 'Species', 'species_label', 'SpeciesLabel']
target_col = None
for c in possible_targets:
    if c in data.columns:
        target_col = c
        break
if target_col is None:
    # fall back to assuming the last column is the target
    target_col = data.columns[-1]
feature_cols = data.columns.drop(target_col)
num_features = len(feature_cols)
print('Detected target column:', target_col)
print('Number of features:', num_features)
# Out:
# Detected target column: species
# Number of features: 4

# %%
# Question #2: What are the features in the dataset? Show the code that lists the feature names
print('Feature columns:')
print(list(feature_cols))
# Out:
# Feature columns:
# ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']

# %%
# Question #3: How many species are there in the dataset? Show the code that extracts this number
num_species = data[target_col].nunique()
print("Number of species:", num_species)
# Out:
# Number of species: 3

# %%
# We are going to train a classifier using Keras on the Penguin dataset
# before we do, let's split the dataset into data and classes, where the classes are in the species columns
# The data will be in X and the species will be in y

# Question #4: Assign the features to the X and the labels to y - show the code that creates X and y
X = data[feature_cols].copy()
y_raw = data[target_col].copy()
# encode labels to integers (0..n-1) to be compatible with Keras to_categorical later
le = LabelEncoder()
y = le.fit_transform(y_raw)
print('X shape:', X.shape)
print('y shape:', y.shape)
print('Label classes:', list(le.classes_))
# Out:
# X shape: (333, 4)
# y shape: (333,)
# Label classes: [np.int64(0), np.int64(1), np.int64(2)]

# %%
# To reduce any potential bias, let's standardize the data in the X dataframe
# use the standard scaler to scale X

# Question #5: complete the code below so it results in a scaled X dataframe. Let's call the scaled version X for simplicity
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=feature_cols)
print('Scaled X: mean ~', X.values.mean().round(3), 'std ~', X.values.std().round(3))
# Out:
# Scaled X: mean ~ -0.0 std ~ 1.0

# %%
# Let's split the dataset into training and testing sets

# Question #6: complete the code below to split X and y into training and testing sets with 20% testing and a randomSeed=42
import sklearn.model_selection as model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X.values, y, test_size=0.2, random_state=42)
print('Train shape:', X_train.shape, 'Test shape:', X_test.shape)
# Out:
# Train shape: (266, 4) Test shape: (67, 4)

# %%
# Let's make sure y values are recorded as categorical
#from tensorflow.keras.to_categorical import to_categorical
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
print('y_train shape after to_categorical:', y_train.shape)
# Out:
# y_train shape after to_categorical: (266, 3)

# %%
# We are now ready to train our classifiers using the Keras APIs
# Let's start with the Keras Sequential API
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Defining our model as sequential
model = Sequential()

# %%
# Here is the code that sends the input X_train into a model with 32 nodes in the first hidden layer
model.add(Dense(units=32, activation='relu', input_shape=(X_train.shape[1],), name='input'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Question #7: show code that adds another dense hidden layer with another 32 nodes
model.add(Dense(units=32, activation='relu', name='hidden2'))

# %%
# Question #8: show code that adds the output layer using softmax. Remember that there are three output nodes (3 species)
model.add(Dense(units=3, activation='softmax', name='output'))

# %%
# Question #9: use model summary to confirm the model you built - show the function call below
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (Dense)                   │ (None, 32)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,315 (5.14 KB)
#  Trainable params: 1,315 (5.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Question #10: compile the code using a) categorical_crossentropy for the loss function, b) stochastic gradient descent with a 0.01 learning rate as the optimizer, and c) accuracy as the metric
from keras.optimizers import SGD
opt = SGD(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
print('Model compiled')
# Out:
# Model compiled

# %%
# Question #11: train the model using using a) a batch size of 16, b) 50 epochs (iterations), and a validation split of 20%
#
perf = model.fit(X_train, y_train, batch_size=16, epochs=50, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/50
# 14/14 - 1s - 77ms/step - accuracy: 0.3160 - loss: 1.0582 - val_accuracy: 0.5556 - val_loss: 0.9817
# Epoch 2/50
# 14/14 - 0s - 9ms/step - accuracy: 0.5708 - loss: 0.9668 - val_accuracy: 0.8704 - val_loss: 0.8873
# Epoch 3/50
# 14/14 - 0s - 9ms/step - accuracy: 0.7406 - loss: 0.8836 - val_accuracy: 0.8704 - val_loss: 0.8069
# Epoch 4/50
# 14/14 - 0s - 9ms/step - accuracy: 0.7972 - loss: 0.8117 - val_accuracy: 0.8519 - val_loss: 0.7359
# Epoch 5/50
# 14/14 - 0s - 8ms/step - accuracy: 0.8160 - loss: 0.7474 - val_accuracy: 0.8519 - val_loss: 0.6671
# Epoch 6/50
# 14/14 - 0s - 9ms/step - accuracy: 0.8302 - loss: 0.6863 - val_accuracy: 0.8519 - val_loss: 0.6084
# Epoch 7/50
# 14/14 - 0s - 10ms/step - accuracy: 0.8443 - loss: 0.6331 - val_accuracy: 0.8519 - val_loss: 0.5543
# Epoch 8/50
# 14/14 - 0s - 9ms/step - accuracy: 0.8443 - loss: 0.5845 - val_accuracy: 0.8519 - val_loss: 0.5062
# Epoch 9/50
# 14/14 - 0s - 9ms/step - accuracy: 0.8538 - loss: 0.5412 - val_accuracy: 0.8889 - val_loss: 0.4649
# Epoch 10/50
# 14/14 - 0s - 9ms/step - accuracy: 0.8585 - loss: 0.5023 - val_accuracy: 0.8889 - val_loss: 0.4279
# Epoch 11/50
# 14/14 - 0s - 8ms/step - accuracy: 0.8679 - loss: 0.4678 - val_accuracy: 0.8889 - val_loss: 0.3957
# Epoch 12/50
# 14/14 - 0s - 9ms/step - accuracy: 0.8774 - loss: 0.4367 - val_accuracy: 0.8889 - val_loss: 0.3668
# Epoch 13/50
# 14/14 - 0s - 9ms/step - accuracy: 0.8821 - loss: 0.4084 - val_accuracy: 0.8889 - val_loss: 0.3412
# Epoch 14/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9009 - loss: 0.3829 - val_accuracy: 0.8889 - val_loss: 0.3175
# Epoch 15/50
# 14/14 - 0s - 10ms/step - accuracy: 0.9057 - loss: 0.3588 - val_accuracy: 0.8889 - val_loss: 0.2960
# Epoch 16/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9245 - loss: 0.3358 - val_accuracy: 0.8889 - val_loss: 0.2763
# Epoch 17/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9292 - loss: 0.3154 - val_accuracy: 0.9074 - val_loss: 0.2589
# Epoch 18/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9292 - loss: 0.2964 - val_accuracy: 0.9259 - val_loss: 0.2431
# Epoch 19/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9340 - loss: 0.2796 - val_accuracy: 0.9259 - val_loss: 0.2289
# Epoch 20/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9434 - loss: 0.2641 - val_accuracy: 0.9630 - val_loss: 0.2153
# Epoch 21/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9528 - loss: 0.2485 - val_accuracy: 0.9630 - val_loss: 0.2034
# Epoch 22/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9575 - loss: 0.2355 - val_accuracy: 0.9630 - val_loss: 0.1924
# Epoch 23/50
# 14/14 - 0s - 10ms/step - accuracy: 0.9575 - loss: 0.2229 - val_accuracy: 0.9630 - val_loss: 0.1827
# Epoch 24/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9623 - loss: 0.2120 - val_accuracy: 0.9630 - val_loss: 0.1742
# Epoch 25/50
# 14/14 - 0s - 14ms/step - accuracy: 0.9717 - loss: 0.2016 - val_accuracy: 0.9630 - val_loss: 0.1657
# Epoch 26/50
# 14/14 - 0s - 21ms/step - accuracy: 0.9670 - loss: 0.1921 - val_accuracy: 0.9630 - val_loss: 0.1579
# Epoch 27/50
# 14/14 - 0s - 12ms/step - accuracy: 0.9717 - loss: 0.1832 - val_accuracy: 0.9630 - val_loss: 0.1504
# Epoch 28/50
# 14/14 - 0s - 20ms/step - accuracy: 0.9717 - loss: 0.1748 - val_accuracy: 0.9815 - val_loss: 0.1437
# Epoch 29/50
# 14/14 - 0s - 14ms/step - accuracy: 0.9764 - loss: 0.1666 - val_accuracy: 0.9815 - val_loss: 0.1375
# Epoch 30/50
# 14/14 - 0s - 14ms/step - accuracy: 0.9764 - loss: 0.1595 - val_accuracy: 0.9815 - val_loss: 0.1316
# Epoch 31/50
# 14/14 - 0s - 12ms/step - accuracy: 0.9811 - loss: 0.1527 - val_accuracy: 1.0000 - val_loss: 0.1260
# Epoch 32/50
# 14/14 - 0s - 14ms/step - accuracy: 0.9764 - loss: 0.1459 - val_accuracy: 1.0000 - val_loss: 0.1210
# Epoch 33/50
# 14/14 - 0s - 14ms/step - accuracy: 0.9764 - loss: 0.1401 - val_accuracy: 1.0000 - val_loss: 0.1164
# Epoch 34/50
# 14/14 - 0s - 21ms/step - accuracy: 0.9858 - loss: 0.1346 - val_accuracy: 0.9815 - val_loss: 0.1123
# Epoch 35/50
# 14/14 - 0s - 17ms/step - accuracy: 0.9858 - loss: 0.1295 - val_accuracy: 0.9815 - val_loss: 0.1082
# Epoch 36/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9858 - loss: 0.1246 - val_accuracy: 0.9815 - val_loss: 0.1045
# Epoch 37/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9858 - loss: 0.1201 - val_accuracy: 1.0000 - val_loss: 0.1008
# Epoch 38/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9858 - loss: 0.1159 - val_accuracy: 0.9815 - val_loss: 0.0977
# Epoch 39/50
# 14/14 - 0s - 12ms/step - accuracy: 0.9858 - loss: 0.1123 - val_accuracy: 0.9815 - val_loss: 0.0947
# Epoch 40/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9906 - loss: 0.1086 - val_accuracy: 1.0000 - val_loss: 0.0916
# Epoch 41/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9906 - loss: 0.1051 - val_accuracy: 1.0000 - val_loss: 0.0889
# Epoch 42/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9906 - loss: 0.1017 - val_accuracy: 1.0000 - val_loss: 0.0863
# Epoch 43/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9858 - loss: 0.0985 - val_accuracy: 1.0000 - val_loss: 0.0839
# Epoch 44/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9906 - loss: 0.0957 - val_accuracy: 1.0000 - val_loss: 0.0816
# Epoch 45/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9906 - loss: 0.0931 - val_accuracy: 1.0000 - val_loss: 0.0794
# Epoch 46/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9906 - loss: 0.0904 - val_accuracy: 1.0000 - val_loss: 0.0773
# Epoch 47/50
# 14/14 - 0s - 9ms/step - accuracy: 0.9906 - loss: 0.0881 - val_accuracy: 1.0000 - val_loss: 0.0755
# Epoch 48/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9906 - loss: 0.0857 - val_accuracy: 1.0000 - val_loss: 0.0736
# Epoch 49/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9906 - loss: 0.0836 - val_accuracy: 1.0000 - val_loss: 0.0719
# Epoch 50/50
# 14/14 - 0s - 8ms/step - accuracy: 0.9906 - loss: 0.0816 - val_accuracy: 1.0000 - val_loss: 0.0702

# %%
# use this code to plot the training metrics
plt.plot(perf.history['loss'])
plt.plot(perf.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

# %%
# Question #12 using the above code as example, plot the accuracy for the training and validation
# change the labels accordingly
plt.plot(perf.history['accuracy'])
plt.plot(perf.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

# %%
# Using model.predict on X_test to get the predictions
class_predictions = np.argmax(model.predict(X_test), axis=-1)
print('Sample predictions (first 10):', class_predictions[:10])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Sample predictions (first 10): [0 2 0 1 0 2 2 1 1 1]

# %%
# Question #13
# write some code that will calulate the accuracy of the model by comparing y_test to class_predictions
# the answer must be in percentages
test_accuracy = np.round(np.mean(class_predictions == y_test) * 100, 2)
print('Test accuracy (%):', test_accuracy)
# Out:
# Test accuracy (%): 97.01

# %%
# Question #14 how does the test accuracy compare to the training accuracy?
train_acc_final = perf.history['accuracy'][-1] if 'accuracy' in perf.history else None
val_acc_final = perf.history['val_accuracy'][-1] if 'val_accuracy' in perf.history else None
print('Final training accuracy:', train_acc_final)
print('Final validation accuracy:', val_acc_final)
print('Final test accuracy (%):', test_accuracy)
# Out:
# Final training accuracy: 0.9905660152435303
# Final validation accuracy: 1.0
# Final test accuracy (%): 97.01

# %%
# Question #15 run the following code to printout the results of your comparison
print("Test Accuracy : " + str(test_accuracy) + '%')
print("Predictions :")
print(class_predictions)
print("Targets :")
print(np.asarray(y_test,dtype="int32"))
# Out:
# Test Accuracy : 97.01%
# Predictions :
# [0 2 0 1 0 2 2 1 1 1 0 0 0 0 2 0 0 1 0 2 0 0 2 1 0 0 1 2 1 2 1 2 0 0 2 2 1
#  1 0 0 0 0 1 1 0 0 2 0 0 2 0 1 1 0 0 1 0 0 1 1 0 2 2 0 0 2 0]
# Targets :
# [0 2 0 1 0 2 2 1 1 1 0 0 2 0 2 0 0 1 0 2 0 0 2 1 0 0 1 2 1 2 1 2 0 0 2 2 1
#  1 0 0 0 0 1 1 0 0 2 0 0 2 0 1 1 0 0 1 0 0 1 1 2 2 2 0 0 2 0]
